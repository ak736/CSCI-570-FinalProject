# %% [markdown]
# This module is responsible for generating the final two DNA sequences required for the sequence alignment algorithms, based on the input format specified in the project instructions.

# %% [markdown]
# **How to Import**

# %%
from input_generator import parse_input_file

# %% [markdown]
# **How to Use**

# %%
X, Y = parse_input_file("sample_input.txt")

# %% [markdown]
# X and Y are the two fully generated strings that should be passed to the alignment algorithms.

# %% [markdown]
# **Notes**

# %% [markdown]
# This module should be included or copied into both basic.py and efficient.py files.
